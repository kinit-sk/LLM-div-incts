# %%
import openai
import pandas as pd
import os
import numpy as np
from ast import literal_eval
import json
import pickle
import time

# %%
# run this to load the now saved DF
df_train = pd.read_csv('challenge_data_new/ag_news/train_news.csv')

# %% [markdown]
# ## Only GPT

# %%
from openai import OpenAI

client = OpenAI(
  organization='', api_key=""
)

# %%
def request_response_from_gpt(prompt):
    response = client.chat.completions.create(
        model="gpt-4-0314",
        #prompt=prompt,
        messages=[
            {"role": "system", "content": "You are a crowdsourcing worker that earns a living through creating paraphrases."},
            {"role": "user", "content": prompt}],
        temperature=1,
        frequency_penalty=0.0,
        presence_penalty=1.5,
        n=1)
    return response

# %%
def request_with_checks(prompt):
    success = False
    count = 0
    while not success:
        if count > 0:
            print(f'Retrying with again. Current number of retries: {count}')
        if count >= 10:
            raise Exception('Too many attempts')
        try:
            response = request_response_from_gpt(prompt)
            sucess = True
            break
        except openai.error.RateLimitError as e:
            print(e)
            time.sleep(10)
            count += 1
        except openai.error.APIConnectionError as e:
            print(e)
            time.sleep(5)
            count += 1
        except openai.error.APIError or openai.error.JSONDecodeError as e:
            print(e)
            time.sleep(5)
            count += 1
        except openai.error.Timeout as e:
            print(e)
            time.sleep(5)
            count += 1
        except openai.error.ServiceUnavailableError as e:
            print(e)
            time.sleep(5)
            count += 1
    return response

# %%
def collect_samples(dct_final_prompts, time_sleep: int=1):
    dct_responses = {}
    for idx, key in enumerate(dct_final_prompts):
        print("Now on label no. {} out of {}.".format(idx, len(dct_final_prompts.keys())))
        dct_responses[key] = []
        for prompt in dct_final_prompts[key]:
            #print(prompt)
            response = request_with_checks(prompt)
            dct_responses[key].append(response)
            time.sleep(time_sleep)
    return dct_responses

# %%
import re
import string

def filter_responses(dct_responses):
    dct_df = {'label': [], 'text': [], 'seed': []}
    for key in dct_responses:
        for responses in dct_responses[key]:
            for response in responses[0].choices:
                contents = response.message.content.split('\n')
                for content in contents:
                    if len(content) == 0:
                        continue
                    if content[0] == '1' or content[0] == '2' or content[0] == '3':
                        content = content[3:]
                    dct_df['label'].append(key)
                    dct_df['text'].append(content)
                    dct_df['seed'].append(responses[1])
                    
    fb_0 = pd.DataFrame.from_dict(dct_df)
                    
    fb_0['text']=fb_0['text'].apply(lambda x: x.lower())
    fb_0['text']=fb_0['text'].apply(lambda x: x.replace('"',''))

    fb_0['text']=fb_0['text'].apply(lambda x: re.sub('[%s]' % re.escape(string.punctuation), '', x))
    
    return fb_0

# %% [markdown]
# # rest prepare

# %%
def change_label_except_for(x, label):
    if x == label:
        return 1
    else:
        return 0
    
from nltk.corpus import stopwords

stops = set(stopwords.words("english"))
def cleantext(string):
    text = string.split()
    text = [w for w in text if not w in stops]
    text = " ".join(text)
    return text

from sklearn import svm
from sklearn.feature_extraction.text import CountVectorizer

def get_fit_svm_linear_and_count_vectorizer(df_orig):
    vectorizer = CountVectorizer()
    X = vectorizer.fit_transform(df_orig['text'])
    x=X.toarray()
    y=df_orig['label']
    model=svm.SVC(kernel='linear')
    model.fit(x,y)
    return model, vectorizer, X

def get_freqs(vectorizer, X):
    feature_names = vectorizer.get_feature_names_out()
    dct = {'word': [], 'freq': []}
    for freq, word in zip(np.asarray(X.sum(axis=0))[0], feature_names):
        dct['word'].append(word)
        dct['freq'].append(freq)

    return pd.DataFrame.from_dict(dct)

def get_coefficients(model, vectorizer):
    feature_names = vectorizer.get_feature_names_out()
    coefs_with_fns = sorted(zip(model.coef_[0], feature_names)) 
    df=pd.DataFrame(coefs_with_fns)
    df.columns='coefficient','word'
    return df.sort_values(by='coefficient')

import spacy
from spacy import displacy

# use random=True for ablated version of the method
def get_taboo_w_for_df_no_ner(df_orig, no_taboo_w, seed_samples_dct, random=False):
    dct_taboo_w_per_label = {}

    NER = spacy.load("en_core_web_sm")

    # we gather taboowords for each label in a one (desired label) vs. one (other labels) setting
    labels = list(set(df_orig['label']))
    for label in labels:
        # reset dataframe
        sub_df_orig = df_orig.copy()
        sub_df_orig['text'] = sub_df_orig['text'].map(lambda x: cleantext(x))
        # set setting to one vs one
        sub_df_orig['label'] = sub_df_orig['label'].map(lambda x: change_label_except_for(x, label))

        model, vectorizer, X = get_fit_svm_linear_and_count_vectorizer(sub_df_orig)
        freqs = get_freqs(vectorizer, X)
        coeffs = get_coefficients(model, vectorizer)
        
        sents = seed_samples_dct[label]
        ners = set()
        for sent in sents:
            res = NER(sent.lower())
            for txt in res.ents:
                subs = set(txt.text.lower().split())
                ners = ners.union(subs)
            
        joined = coeffs.set_index('word').join(freqs.set_index('word'), lsuffix='_caller', rsuffix='_other')
        joined_rel = joined[joined['freq'] >= 5].sort_values(by=['freq'])

        if random:
            joined_rel = joined_rel.sample(frac=1)
        else:   
            joined_rel = joined_rel.sort_values(by=['coefficient'])
            
        taboo_w_without_ints = list(joined_rel.index)
        taboo_w_without_ints = list(filter(lambda word: not word.isdigit(), taboo_w_without_ints))
        
        taboo_w_without_ners = list(filter(lambda word: not word in ners, taboo_w_without_ints))
        
        dct_taboo_w_per_label[label] = taboo_w_without_ners[-no_taboo_w:]
        
    return dct_taboo_w_per_label

# %%
from sentence_transformers import SentenceTransformer
model = SentenceTransformer('paraphrase-MiniLM-L6-v2')

def get_embs_for_sents(df_pd) -> dict:
    sents_dct = {}
    emb_dct = {}

    for dct in df_pd.to_dict('records'):
        if dct['label'] in sents_dct:
            sents_dct[dct['label']].append(dct['text'])
        else:
            sents_dct[dct['label']] = [dct['text']]
            
    for label in sents_dct.keys():
        emb_dct[label] = {'emb': model.encode(sents_dct[label]), 'sent': sents_dct[label]}
    return emb_dct

def calculate_outliers(df_pd) -> dict:
    embs_dct = get_embs_for_sents(df_pd)
    mean_dct = {}
    pandas_dct = {'label': [], 'distance': [], 'text': []}
    
    # calculate mean vector per label
    for label in embs_dct:
        mean_dct[label] = embs_dct[label]['emb'].mean(axis=0)
        
    # calculate distance from the mean vector per label
    for label in embs_dct:
        mean_emb = mean_dct[label]
        for (sent_emb, sent) in zip(embs_dct[label]['emb'], embs_dct[label]['sent']):
            dist = np.linalg.norm(mean_emb - sent_emb)
            pandas_dct['label'].append(label)
            pandas_dct['distance'].append(dist)
            pandas_dct['text'].append(sent)                        
    return pd.DataFrame.from_dict(pandas_dct)

def get_seed_sentences_per_labels(outliers_df, dct_phrases: dict, random=False) -> dict:
    dct_seeds_per_label = {}
    for label in dct_phrases.keys():
        no_samples = len(dct_phrases[label])
        if random:
            sub_outlier_df = outliers_df[outliers_df['label'] == label].sample(frac=1)
        else:    
            sub_outlier_df = outliers_df[outliers_df['label'] == label].sort_values(by=['distance'], ascending=False)
        dct_seeds_per_label[label] = list(sub_outlier_df.head(no_samples)['text'])
    return dct_seeds_per_label

# %% [markdown]
# ## all the good things

# %%
NO_TRY = 0

N_SAMPLES = 6
get_subsampled = df_train.groupby('label', group_keys=False).apply(lambda x: x.sample(N_SAMPLES))

get_subsampled.to_csv('challenge_data_new/ag_news/gpt4/'+str(NO_TRY)+'/seeds.csv', index=False)

# %%
dct_phrases = {}
for key in set(get_subsampled['label']):
    dct_phrases[key] = list(get_subsampled[get_subsampled['label'] == key]['text'])

default_prompt = 'Rephrase an original question or statement 3 times. Original phrase: "{}".'

# %%
dct_final_prompts = {}

for key in dct_phrases:
    dct_final_prompts[key] = []
    for phrase in dct_phrases[key]:
        dct_final_prompts[key].append((default_prompt.format(phrase), phrase))

# %%
def collect_samples(dct_final_prompts):
    dct_responses = {}

    for idx, key in enumerate(dct_final_prompts):
        print(str(idx))
        dct_responses[key] = []
        for prompt in dct_final_prompts[key]:
            print(prompt[0])
            response = request_with_checks(prompt[0])
            dct_responses[key].append((response, prompt[1]))
            time.sleep(1)
            
    return dct_responses

# %%
dct_responses = collect_samples(dct_final_prompts)
# Out:
# 0
# Rephrase an original question or statement 3 times. Original phrase: "britain denies political 39 deployment in iraq british prime minister tony blair 39s government yesterday rejected claims from opposition lawmakers that a redeployment of british troops in iraq would be a political show of support for the administration of us president george w bush before presidential".
# Rephrase an original question or statement 3 times. Original phrase: "army deserter jenkins released in japan us army deserter charles jenkins was released from military jail on saturday after serving 25 days for abandoning his squadron in 1965 and defecting to north korea where he lived for nearly four decades".
# Rephrase an original question or statement 3 times. Original phrase: "troops start new offensive near baghdad about 5000 us marines british troops and iraqi forces began an offensive yesterday aimed at clearing insurgents from a cluster of dusty small towns south of baghdad".
# Rephrase an original question or statement 3 times. Original phrase: "preemption not on cards sharon jerusalem israeli prime minister ariel sharon said iran and its nuclear ambitions represent a very great danger to the jewish state but played down the prospect of a preemptive strike on its atomic facilities".
# Rephrase an original question or statement 3 times. Original phrase: "japan eases arms export ban for new missile shield  tokyo reuters  japan eased a blanket ban on arms exports  on friday to open the way for joint production of a new missile  shield with the united states but said it would still refrain  from most other weapons exports".
# Rephrase an original question or statement 3 times. Original phrase: "milosevic lawyers plead to quit appeals court judges hear from slobodan milosevics lawyers who want  the exyugoslav president to defend himself".
# 1
# Rephrase an original question or statement 3 times. Original phrase: "eagles 34 browns 31 ot the only sign that terrell owens didn 39t have an issue with was the scoreboard david akers kicked a 50yard field goal in overtime and donovan mcnabb matched a career high with four touchdown passes  two".
# Rephrase an original question or statement 3 times. Original phrase: "jackson texas stop topranked tennessee tiffany jackson scored 9 of her 19 points early in the second half as no 4 texas broke open a close game and went on to a 7459 win over no 1 tennessee last night in austin texas".
# Rephrase an original question or statement 3 times. Original phrase: "bruandwo back with higher bid woolworths has cemented its advantage in the tussle for australian leisure and hospitality less than an hour before it would have ceded victory to coles myer".
# Rephrase an original question or statement 3 times. Original phrase: "at ampt to cut 7400 more jobs take us114b writedown at ampt corp the former monopoly that once dominated the us phone market said thursday it will cut another 20 per cent of its workforce and suffer an asset writedown of us11".
# Rephrase an original question or statement 3 times. Original phrase: "british energy preempts polygon by delisting shares the battle between british energy and rebel shareholders seeking a better deal from the company 39s 5bn restructuring plan intensified yesterday when the nuclear generator announced it was abandoning its london share listing".
# Rephrase an original question or statement 3 times. Original phrase: "delta clips its wings in dallas the links between delta air lines and dallas reach all the way back to the carrier 39s first passenger flight on june 17 1929 a sixseat delta  quottravelair quot flew from dallas to jackson miss".
# Rephrase an original question or statement 3 times. Original phrase: "oracle shares gain amid tech decline  chicago reuters  shares of software maker oracle corp  lta hrefhttpwwwinvestorreuterscomfullquoteaspxtickerorclo targetstocksquickinfofullquotegtorcloltagt rose as much as 8 percent in early trading on  wednesday a day after the company posted strong quarterly  profit fueled by steady demand for its flagship database  products".
# 3
# Rephrase an original question or statement 3 times. Original phrase: "cingular to cut 7000 jobs to trim costs after buyout cingular wireless the nations largest cellular phone company plans to cut about 10 percent of its work force as a result of its purchase of at t wireless".
# Rephrase an original question or statement 3 times. Original phrase: "cisco touts core router customers smaller platform a research center in pittsburgh as well as a broadband service provider and an academic network in japan all have bought cisco systems first totally new core routing platform in seven years which was introduced with fanfare in june the company announced monday".
# Rephrase an original question or statement 3 times. Original phrase: "new logo and tagline for xerox xerox is saying goodbye to an old slogan as it moves beyond the document company to include technology and consulting".
# Rephrase an original question or statement 3 times. Original phrase: "oracle raps peoplesoft customer refund program oracle tells a judge the antitakeover measure is unnecessary and ties the hands of a future board of directors".
# Rephrase an original question or statement 3 times. Original phrase: "the new browser on the block imagine if everyone watched television using the same set listened to the radio using the same audio system or surfed the web using the same browser".
# Rephrase an original question or statement 3 times. Original phrase: "a googlemicrosoft war there 39s been a lot of gossip about the upcoming google browser and its possible impact on microsoft it 39s hard to predict what will happen but it won 39t surprise me if an allout war between google and microsoft ensues".

# %%
fb_0 = filter_responses(dct_responses)
fb_0.drop_duplicates().to_csv('challenge_data_new/ag_news/gpt4/'+str(NO_TRY)+'/news_1_seeds.csv', index=False)

# %%
fb_0 = pd.read_csv('challenge_data_new/ag_news/gpt4/'+str(NO_TRY)+'/news_0_seeds.csv')
dct_phrases = fb_0.groupby('label')['seed'].apply(set).to_dict()
dct_taboo = get_taboo_w_for_df_no_ner(fb_0, 3, dct_phrases)

# %%
defaul_taboo_prompt = 'Rephrase an original question or statement 3 times. Original phrase: "{}". Don’t use the words “{}”, “{}” or “{}” in your responses.'

dct_final_prompts = {}

for key in dct_phrases:
    dct_final_prompts[key] = []
    for phrase in dct_phrases[key]:
        dct_final_prompts[key].append((defaul_taboo_prompt.format(phrase, dct_taboo[key][0], dct_taboo[key][1], dct_taboo[key][2]), phrase))

# %%
dct_responses = collect_samples(dct_final_prompts)
# Out:
# 0
# Rephrase an original question or statement 3 times. Original phrase: "army deserter jenkins released in japan us army deserter charles jenkins was released from military jail on saturday after serving 25 days for abandoning his squadron in 1965 and defecting to north korea where he lived for nearly four decades". Don’t use the words “prime”, “minister” or “president” in your responses.
# Rephrase an original question or statement 3 times. Original phrase:
in your responses.
# Rephrase an original question or statement 3 times. Original phrase: "at ampt to cut 7400 more jobs take us114b writedown at ampt corp the former monopoly that once dominated the us phone market said thursday it will cut another 20 per cent of its workforce and suffer an asset writedown of us11". Don’t use the words “shares”, “interest” or “billion” in your responses.
# Rephrase an original question or statement 3 times. Original phrase: "oracle shares gain amid tech decline  chicago reuters  shares of software maker oracle corp  lta hrefhttpwwwinvestorreuterscomfullquoteaspxtickerorclo targetstocksquickinfofullquotegtorcloltagt rose as much as 8 percent in early trading on  wednesday a day after the company posted strong quarterly  profit fueled by steady demand for its flagship database  products". Don’t use the words “shares”, “interest” or “billion” in your responses.
# Rephrase an original question or statement 3 times. Original phrase: "hungarian central bank cuts key interest rate by half percentage point afp afp  the hungarian central bank cut its benchmark interest rate by 50 basis points from 115 percent to 110 percent the bank said in a statement posted on its website". Don’t use the words “shares”, “interest” or “billion” in your responses.
# Rephrase an original question or statement 3 times. Original phrase: "delta clips its wings in dallas the links between delta air lines and dallas reach all the way back to the carrier 39s first passenger flight on june 17 1929 a sixseat delta  quottravelair quot flew from dallas to jackson miss". Don’t use the words “shares”, “interest” or “billion” in your responses.
# 3
# Rephrase an original question or statement 3 times. Original phrase: "new logo and tagline for xerox xerox is saying goodbye to an old slogan as it moves beyond the document company to include technology and consulting". Don’t use the words “technology”, “wireless” or “browser” in your responses.
# Rephrase an original question or statement 3 times. Original phrase: "oracle raps peoplesoft customer refund program oracle tells a judge the antitakeover measure is unnecessary and ties the hands of a future board of directors". Don’t use the words “technology”, “wireless” or “browser” in your responses.
# Rephrase an original question or statement 3 times. Original phrase: "the new browser on the block imagine if everyone watched television using the same set listened to the radio using the same audio system or surfed the web using the same browser". Don’t use the words “technology”, “wireless” or “browser” in your responses.
# Rephrase an original question or statement 3 times. Original phrase: "cisco touts core router customers smaller platform a research center in pittsburgh as well as a broadband service provider and an academic network in japan all have bought cisco systems first totally new core routing platform in seven years which was introduced with fanfare in june the company announced monday". Don’t use the words “technology”, “wireless” or “browser” in your responses.
# Rephrase an original question or statement 3 times. Original phrase: "cingular to cut 7000 jobs to trim costs after buyout cingular wireless the nations largest cellular phone company plans to cut about 10 percent of its work force as a result of its purchase of at t wireless". Don’t use the words “technology”, “wireless” or “browser” in your responses.
# Rephrase an original question or statement 3 times. Original phrase: "a googlemicrosoft war there 39s been a lot of gossip about the upcoming google browser and its possible impact on microsoft it 39s hard to predict what will happen but it won 39t surprise me if an allout war between google and microsoft ensues". Don’t use the words “technology”, “wireless” or “browser” in your responses.

# %%
fb_0 = filter_responses(dct_responses)
fb_0.drop_duplicates().to_csv('challenge_data_new/ag_news/gpt4/'+str(NO_TRY)+'/news_1_taboo.csv', index=False)

# %%
fb_0 = pd.read_csv('challenge_data_new/ag_news/gpt4/'+str(NO_TRY)+'/news_0_seeds.csv').drop_duplicates()
dct_phrases = fb_0.groupby('label')['seed'].apply(set).to_dict()

df_outliers = calculate_outliers(fb_0)
dct_phrases = get_seed_sentences_per_labels(df_outliers, dct_phrases)

# %%
default_prompt = 'Rephrase an original question or statement 3 times. Original phrase: "{}".'

dct_final_prompts = {}

for key in dct_phrases:
    dct_final_prompts[key] = []
    for phrase in dct_phrases[key]:
        dct_final_prompts[key].append((default_prompt.format(phrase), phrase))

# %%
dct_responses = collect_samples(dct_final_prompts)
# Out:
# 0
# Rephrase an original question or statement 3 times. Original phrase: " ".
# Rephrase an original question or statement 3 times. Original phrase: "milosevics attorneys request to withdraw as appellate court judges listen to their appeals wanting the former yugoslav president to represent himself".
# Rephrase an original question or statement 3 times. Original phrase: "cingular wireless the biggest cell phone company in the nation plans on cutting around 10 of its employees which translates to 7000 jobs as a costcutting measure after acquiring att wireless".
# Rephrase an original question or statement 3 times. Original phrase: "in response to its purchase of att wireless cingular wireless americas largest cell phone provider is set to slash about 10 of its workforce eliminating roughly 7000 positions in an effort to reduce costs".
# Rephrase an original question or statement 3 times. Original phrase: "oracle asserts to a judge that peoplesofts customer reimbursement policy is excessive as an antitakeover defense ultimately binding the freedom of any prospective board of directors".
# Rephrase an original question or statement 3 times. Original phrase: "oracle criticizes peoplesofts customer refund program claiming it hinders future board of directors and arguing the antitakeover measure is unneeded".

# %%
fb_0 = filter_responses(dct_responses)
fb_0.drop_duplicates().to_csv('challenge_data_new/ag_news/gpt4/'+str(NO_TRY)+'/news_1_chaining.csv', index=False)

# %%
default_prompt = """Rephrase an original question or statement 3 times. Original phrase: "{}".
###
Example paraphrases:
{}
###
"""

default_hint_prompt = '"{}".'

#use random=True for ablated version
def get_hint_sentences_per_labels(df_outliers, no_samples, dct_phrases, random=False):
    dct_hints_per_sample = {}
    for label in dct_phrases.keys():
        for phrase in dct_phrases[label]:
            sub_df = df_outliers[df_outliers['seed'] == phrase] 
            if random:
                sub_df = sub_df.sample(frac=1)
            else:
                sub_df = sub_df.sort_values(by=['distance'], ascending=False)
            dct_hints_per_sample[phrase] = list(sub_df.head(no_samples)['text'])
    return dct_hints_per_sample

fb_0 = pd.read_csv('challenge_data_new/ag_news/gpt4/'+str(NO_TRY)+'/news_0_seeds.csv').drop_duplicates()
dct_phrases = fb_0.groupby('label')['seed'].apply(set).to_dict()

fb_0 = pd.read_csv('challenge_data_new/ag_news/gpt4/'+str(NO_TRY)+'/news_0_seeds.csv').drop_duplicates()
# comb is done for the second round

df_outliers = calculate_outliers(fb_0)

df_merged = df_outliers.merge(fb_0, how='inner', on='text').drop_duplicates()[['label_x', 'text', 'distance', 'seed']]
df_merged = df_merged.rename(columns={'label_x': 'label'}).dropna()

dct_hints_per_sample = get_hint_sentences_per_labels(df_merged, 3, dct_phrases)

# %%
dct_final_prompts = {}

for key in dct_phrases:
    dct_final_prompts[key] = []
    for phrase in dct_phrases[key]:
        hints = dct_hints_per_sample[phrase]
        str_hints = []
        for hint in hints:
            str_hints.append(default_hint_prompt.format(hint))
        final_hint_str = "\n".join(str_hints) 
        dct_final_prompts[key].append((default_prompt.format(phrase, final_hint_str), phrase))

# %%
dct_responses = collect_samples(dct_final_prompts)
# Out:
# 0
# Rephrase an original question or statement 3 times. Original phrase: "army deserter jenkins released in japan us army deserter charles jenkins was released from military jail on saturday after serving 25 days for abandoning his squadron in 1965 and defecting to north korea where he lived for nearly four decades".
# ###
# Example paraphrases:
# "us army deserter charles jenkins was freed from a military detention center in japan last saturday having served a 25day sentence for defecting to north korea and walking away from his squad in 1965 where he spent nearly 40 years of his life".
# "on saturday charles jenkins was set free from military prison in japan after serving 25 days for deserting his us army unit and defecting to north korea in 1965 where he resided for almost 40 years".
# "after spending 25 days in a military jail for leaving his squadron back in 1965 and fleeing to north korea where he stayed for close to four decades us army deserter charles jenkins was let go in japan on saturday".
# ###
#
# Rephrase an original question or statement 3 times. Original phrase:

# ###
#
# Rephrase an original question or statement 3 times. Original phrase: "oracle shares gain amid tech decline  chicago reuters  shares of software maker oracle corp  lta hrefhttpwwwinvestorreuterscomfullquoteaspxtickerorclo targetstocksquickinfofullquotegtorcloltagt rose as much as 8 percent in early trading on  wednesday a day after the company posted strong quarterly  profit fueled by steady demand for its flagship database  products".
# ###
# Example paraphrases:
# "oracle shares experience growth amidst technology decline according to chicago reuters following robust quarterly earnings powered by persistent demand for their signature database products shares of software manufacturer oracle corp climbed up to 8 at the start of trading on wednesday".
# "amid a tech downturn oracle stocks increase in value chicago reuters reports that on wednesday oracle corps shares experienced an 8 surge during early trading after the software producer announced significant quarterly gains due to consistent interest in its primary database offerings".
# "in spite of the decline in technology sector oracles shares make progress shares of oracle corp a softwaremaking firm witnessed an uptrend of about 8 in initial trades on wednesday as reported by chicago reuters subsequent to the company disclosing solid profit in the recent quarter driven by ongoing demands for its principal database solutions".
# ###
#
# Rephrase an original question or statement 3 times. Original phrase: "hungarian central bank cuts key interest rate by half percentage point afp afp  the hungarian central bank cut its benchmark interest rate by 50 basis points from 115 percent to 110 percent the bank said in a statement posted on its website".
# ###
# Example paraphrases:
# "the hungarian national bank reduces its main interest rate by 05 percent as reported by afp according to a statement on the banks website the benchmark interest rate has been lowered from 115 to 11".
# "as per an announcement on their website and confirmed by afp the central bank of hungary has decreased their key interest rate by half a percentage point thus it moved from 115 down to 11".
# "a 05 reduction in the primary interest rate was implemented by the hungarian central bank an update posted on their site and supported by afp news disclosed consequently the banks vital interest rate shifted from 115 to 11".
# ###
#
# Rephrase an original question or statement 3 times. Original phrase: "delta clips its wings in dallas the links between delta air lines and dallas reach all the way back to the carrier 39s first passenger flight on june 17 1929 a sixseat delta  quottravelair quot flew from dallas to jackson miss".
# ###
# Example paraphrases:
# "the connections between delta air lines and dallas date back to the companys very first passenger flight on june 17 1929 during which a sixpassenger delta travelair embarked on a trip from dallas to jackson mississippi".
# "the roots of delta air lines and its ties to dallas can be traced back to its initial passenger flight on june 17 1929 where a delta travelair with six seats journeyed from dallas to jackson mississippi".
# "in dallas delta trims its wings with connections to delta air lines extending back to the airlines inaugural passenger flight on june 17 1929 when a sixseater travelair took off from dallas and landed in jackson mississippi".
# ###
#
# 3
# Rephrase an original question or statement 3 times. Original phrase: "new logo and tagline for xerox xerox is saying goodbye to an old slogan as it moves beyond the document company to include technology and consulting".
# ###
# Example paraphrases:
# "as xerox transitions from a documentfocused company to encompass technology and consulting it is bidding farewell to its old motto and introducing a fresh logo and tagline".
# "xerox seeks to move forward with a novel logo and catchphrase as it ventures beyond traditional documentbased services into realms of technology and consultancy leaving behind an outdated slogan".
# "with the expansion toward incorporating technology and advisory services xerox is discarding an obsolete phrase in exchange for a modernized logo and tagline to represent their evolving brand".
# ###
#
# Rephrase an original question or statement 3 times. Original phrase: "oracle raps peoplesoft customer refund program oracle tells a judge the antitakeover measure is unnecessary and ties the hands of a future board of directors".
# ###
# Example paraphrases:
# "oracle asserts to a judge that peoplesofts customer reimbursement policy is excessive as an antitakeover defense ultimately binding the freedom of any prospective board of directors".
# "oracle criticizes peoplesofts customer refund program claiming it hinders future board of directors and arguing the antitakeover measure is unneeded".
# "the customer refund program at peoplesoft faces disapproval from oracle stating that it restricts the actions of potential board members while also deeming the antitakeover measure superfluous".
# ###
#
# Rephrase an original question or statement 3 times. Original phrase: "the new browser on the block imagine if everyone watched television using the same set listened to the radio using the same audio system or surfed the web using the same browser".
# ###
# Example paraphrases:
# "imagine a scenario where everyone views tv on the same device listens to radio broadcasts via the same sound system and browses the internet with the same browser  thats what the new browser on the block is like".
# "picture this the new browser on the block resembles a situation where all individuals are using one shared set for watching tv employing the same sound unit for radio listening and accessing websites online through an identical browser".
# "consider the new browser on the block as if everyone were watching television with the same model tuned into the radio with the same audio setup or exploring the internet using a single browser".
# ###
#
# Rephrase an original question or statement 3 times. Original phrase: "cisco touts core router customers smaller platform a research center in pittsburgh as well as a broadband service provider and an academic network in japan all have bought cisco systems first totally new core routing platform in seven years which was introduced with fanfare in june the company announced monday".
# ###
# Example paraphrases:
# "cisco systems announced on monday that their first completely new core routing platform in seven years introduced with great enthusiasm in june has been bought by a research center in pittsburgh a japanese academic network and a broadband service provider as they highlight their core router customers utilizing smaller platforms".
# "the company declared on monday that a pittsburgh research center a broadband service provider and a japanese academic network have all acquired cisco systems first allnew core routing platform in seven years launched amidst celebration in june showcasing their core router customers opting for smaller platforms".
# "a research center in pittsburgh a broadband service provider and an academic network in japan have all purchased cisco systems first entirely new core routing platform in seven years which was unveiled with much excitement in june the company revealed on monday as they promote their core router customers smaller platforms".
# ###
#
# Rephrase an original question or statement 3 times. Original phrase: "cingular to cut 7000 jobs to trim costs after buyout cingular wireless the nations largest cellular phone company plans to cut about 10 percent of its work force as a result of its purchase of at t wireless".
# ###
# Example paraphrases:
# "following the acquisition of att wireless cingular wireless the countrys leading mobile phone firm intends to reduce its workforce by approximately 10 resulting in a loss of 7000 jobs to decrease expenses".
# "cingular wireless the biggest cell phone company in the nation plans on cutting around 10 of its employees which translates to 7000 jobs as a costcutting measure after acquiring att wireless".
# "in response to its purchase of att wireless cingular wireless americas largest cell phone provider is set to slash about 10 of its workforce eliminating roughly 7000 positions in an effort to reduce costs".
# ###
#
# Rephrase an original question or statement 3 times. Original phrase: "a googlemicrosoft war there 39s been a lot of gossip about the upcoming google browser and its possible impact on microsoft it 39s hard to predict what will happen but it won 39t surprise me if an allout war between google and microsoft ensues".
# ###
# Example paraphrases:
# "a lot of talk surrounds the anticipated google browser and the possible repercussions for microsoft predicting the aftermath is challenging but a fierce showdown between google and microsoft might very well occur".
# "the impending google browser and its potential consequences on microsoft have sparked a great deal of chatter while its tough to determine the result an intense conflict between google and microsoft is plausible".
# "there has been much speculation about the forthcoming google browser and how it may affect microsoft  its difficult to foresee the outcome but witnessing a fullscale battle between google and microsoft wouldnt be astonishing".
# ###

# %%
fb_0 = filter_responses(dct_responses)
fb_0.drop_duplicates().to_csv('challenge_data_new/ag_news/gpt4/'+str(NO_TRY)+'/news_1_hints.csv', index=False)

# %% [markdown]
# ## final csvs

# %%
# temporary only
import re
import string

NO_TRY=4

fb_0 = pd.read_csv('challenge_data_new/ag_news/gpt4/'+str(NO_TRY)+'/seeds.csv')
fb_0 = fb_0[['text', 'label']].drop_duplicates()

fb_0['text']=fb_0['text'].apply(lambda x: x.lower())
fb_0['text']=fb_0['text'].apply(lambda x: x.strip())
fb_0['text']=fb_0['text'].apply(lambda x: x.replace('"',''))
fb_0['text']=fb_0['text'].apply(lambda x: re.sub('[%s]' % re.escape(string.punctuation), '', x))

fb_0.to_csv('challenge_data_new/ag_news/gpt4/'+str(NO_TRY)+'/seeds.csv', index=False)

# %%
fb_seeds = pd.read_csv('challenge_data_new/ag_news/gpt4/'+str(NO_TRY)+'/seeds.csv').dropna().reset_index(drop=True).sample(frac=1, replace=False, random_state=1)
fb_0 = pd.read_csv('challenge_data_new/ag_news/gpt4/'+str(NO_TRY)+'/news_0_seeds.csv').dropna().reset_index(drop=True).sample(frac=1, replace=False, random_state=1)
fb_1 = pd.read_csv('challenge_data_new/ag_news/gpt4/'+str(NO_TRY)+'/news_1_seeds.csv').dropna().reset_index(drop=True).sample(frac=1, replace=False, random_state=1)

fb = pd.concat([fb_0, fb_1, fb_seeds], ignore_index=True).drop_duplicates('text').dropna(subset=['text'])

# %%
fb = fb.sample(frac=1).reset_index(drop=True)
fb['text'] = fb['text'].apply(lambda x: x.replace('"',''))
fb = fb[~fb['text'].str.contains("paraphra")]

# %%
fb[['text', 'label']].to_csv('challenge_data_new/ag_news/gpt4/'+str(NO_TRY)+'/news_prompt.csv', index=False)

# %%
fb_1 = pd.read_csv('challenge_data_new/ag_news/gpt4/'+str(NO_TRY)+'/news_1_taboo.csv').dropna(subset=['text']).reset_index(drop=True).sample(frac=1, replace=False, random_state=1)


fb = pd.concat([fb_0, fb_1, fb_seeds], ignore_index=True).drop_duplicates('text').dropna(subset=['text'])
fb = fb[~fb['text'].str.contains("paraphra")]

fb = fb.sample(frac=1).reset_index(drop=True)
fb['text'] = fb['text'].apply(lambda x: x.replace('"',''))

fb[['text', 'label']].to_csv('challenge_data_new/ag_news/gpt4/'+str(NO_TRY)+'/news_taboo.csv', index=False)

# %%
fb_1 = pd.read_csv('challenge_data_new/ag_news/gpt4/'+str(NO_TRY)+'/news_1_chaining.csv').dropna(subset=['text']).reset_index(drop=True).sample(frac=1, replace=False, random_state=1)

fb = pd.concat([fb_0, fb_1, fb_seeds], ignore_index=True).drop_duplicates('text').dropna(subset=['text'])
fb = fb[~fb['text'].str.contains("paraphra")]

fb = fb.sample(frac=1).reset_index(drop=True)
fb['text'] = fb['text'].apply(lambda x: x.replace('"',''))

fb[['text', 'label']].to_csv('challenge_data_new/ag_news/gpt4/'+str(NO_TRY)+'/news_chaining.csv', index=False)

# %%
fb_1 = pd.read_csv('challenge_data_new/ag_news/gpt4/'+str(NO_TRY)+'/news_1_hints.csv').dropna(subset=['text']).reset_index(drop=True).sample(frac=1, replace=False, random_state=1)

fb = pd.concat([fb_0, fb_1, fb_seeds], ignore_index=True).drop_duplicates('text').dropna(subset=['text'])
fb = fb[~fb['text'].str.contains("paraphra")]

fb = fb.sample(frac=1).reset_index(drop=True)
fb['text'] = fb['text'].apply(lambda x: x.replace('"',''))

fb[['text', 'label']].to_csv('challenge_data_new/ag_news/gpt4/'+str(NO_TRY)+'/news_hints.csv', index=False)
