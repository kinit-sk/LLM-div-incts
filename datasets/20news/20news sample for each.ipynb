# %%
import openai

import pandas as pd
import os
import numpy as np
from ast import literal_eval
import json
import pickle
import time

# %%
df_train = pd.read_csv('challenge_data_new/20news/train_news.csv')

# %% [markdown]
# ## Only GPT

# %%
from openai import OpenAI

client = OpenAI(
  organization='VERY-OWN', api_key="YOUR-OWN"
)

# %%
def request_response_from_gpt(prompt):
    response = client.chat.completions.create(
        model="gpt-4-0314", # replace with chatgpt version
        #prompt=prompt,
        messages=[
            {"role": "system", "content": "You are a crowdsourcing worker that earns a living through creating paraphrases."},
            {"role": "user", "content": prompt}],
        temperature=1,
        frequency_penalty=0.0,
        presence_penalty=1.5,
        n=1)
    return response

# %%
def request_with_checks(prompt):
    success = False
    count = 0
    while not success:
        if count > 0:
            print(f'Retrying with again. Current number of retries: {count}')
        if count >= 10:
            raise Exception('Too many attempts')
        try:
            response = request_response_from_gpt(prompt)
            sucess = True
            break
        except openai.error.RateLimitError as e:
            print(e)
            time.sleep(10)
            count += 1
        except openai.error.APIConnectionError as e:
            print(e)
            time.sleep(5)
            count += 1
        except openai.error.APIError or openai.error.JSONDecodeError as e:
            print(e)
            time.sleep(5)
            count += 1
        except openai.error.Timeout as e:
            print(e)
            time.sleep(5)
            count += 1
        except openai.error.ServiceUnavailableError as e:
            print(e)
            time.sleep(5)
            count += 1
    return response

# %%
def collect_samples(dct_final_prompts, time_sleep: int=1):
    dct_responses = {}
    for idx, key in enumerate(dct_final_prompts):
        print("Now on label no. {} out of {}.".format(idx, len(dct_final_prompts.keys())))
        dct_responses[key] = []
        for prompt in dct_final_prompts[key]:
            #print(prompt)
            response = request_with_checks(prompt)
            dct_responses[key].append(response)
            time.sleep(time_sleep)
    return dct_responses

# %%
import re
import string

def filter_responses(dct_responses):
    dct_df = {'label': [], 'text': [], 'seed': []}
    for key in dct_responses:
        for responses in dct_responses[key]:
            for response in responses[0].choices:
                contents = response.message.content.split('\n')
                for content in contents:
                    if len(content) == 0:
                        continue
                    if content[0] == '1' or content[0] == '2' or content[0] == '3':
                        content = content[3:]
                    dct_df['label'].append(key)
                    dct_df['text'].append(content)
                    dct_df['seed'].append(responses[1])
                    
    fb_0 = pd.DataFrame.from_dict(dct_df)
                    
    fb_0['text']=fb_0['text'].apply(lambda x: x.lower())
    fb_0['text']=fb_0['text'].apply(lambda x: x.replace('"',''))

    fb_0['text']=fb_0['text'].apply(lambda x: re.sub('[%s]' % re.escape(string.punctuation), '', x))
    
    return fb_0

# %% [markdown]
# # rest prepare

# %%
def change_label_except_for(x, label):
    if x == label:
        return 1
    else:
        return 0
    
from nltk.corpus import stopwords

stops = set(stopwords.words("english"))
def cleantext(string):
    text = string.split()
    text = [w for w in text if not w in stops]
    text = " ".join(text)
    return text

from sklearn import svm
from sklearn.feature_extraction.text import CountVectorizer

def get_fit_svm_linear_and_count_vectorizer(df_orig):
    vectorizer = CountVectorizer()
    X = vectorizer.fit_transform(df_orig['text'])
    x=X.toarray()
    y=df_orig['label']
    model=svm.SVC(kernel='linear')
    model.fit(x,y)
    return model, vectorizer, X

def get_freqs(vectorizer, X):
    feature_names = vectorizer.get_feature_names_out()
    dct = {'word': [], 'freq': []}
    for freq, word in zip(np.asarray(X.sum(axis=0))[0], feature_names):
        dct['word'].append(word)
        dct['freq'].append(freq)

    return pd.DataFrame.from_dict(dct)

def get_coefficients(model, vectorizer):
    feature_names = vectorizer.get_feature_names_out()
    coefs_with_fns = sorted(zip(model.coef_[0], feature_names)) 
    df=pd.DataFrame(coefs_with_fns)
    df.columns='coefficient','word'
    return df.sort_values(by='coefficient')

import spacy
from spacy import displacy

def get_taboo_w_for_df_no_ner(df_orig, no_taboo_w, seed_samples_dct):
    dct_taboo_w_per_label = {}

    NER = spacy.load("en_core_web_sm")

    # we gather taboowords for each label in a one (desired label) vs. one (other labels) setting
    labels = list(set(df_orig['label']))
    for label in labels:
        # reset dataframe
        sub_df_orig = df_orig.copy()
        sub_df_orig['text'] = sub_df_orig['text'].map(lambda x: cleantext(x))
        # set setting to one vs one
        sub_df_orig['label'] = sub_df_orig['label'].map(lambda x: change_label_except_for(x, label))

        model, vectorizer, X = get_fit_svm_linear_and_count_vectorizer(sub_df_orig)
        freqs = get_freqs(vectorizer, X)
        coeffs = get_coefficients(model, vectorizer)
        
        sents = seed_samples_dct[label]
        ners = set()
        for sent in sents:
            res = NER(str(sent).lower())
            for txt in res.ents:
                subs = set(txt.text.lower().split())
                ners = ners.union(subs)
            
        joined = coeffs.set_index('word').join(freqs.set_index('word'), lsuffix='_caller', rsuffix='_other')
        joined_rel = joined[joined['freq'] >= 5].sort_values(by=['freq'])

        joined_rel = joined_rel.sort_values(by=['coefficient'])
        taboo_w_without_ints = list(joined_rel.index)
        taboo_w_without_ints = list(filter(lambda word: not word.isdigit(), taboo_w_without_ints))
        
        taboo_w_without_ners = list(filter(lambda word: not word in ners, taboo_w_without_ints))
        
        dct_taboo_w_per_label[label] = taboo_w_without_ners[-no_taboo_w:]
        
    return dct_taboo_w_per_label

# %%
from sentence_transformers import SentenceTransformer
model = SentenceTransformer('paraphrase-MiniLM-L6-v2')

def get_embs_for_sents(df_pd) -> dict:
    sents_dct = {}
    emb_dct = {}

    for dct in df_pd.to_dict('records'):
        if dct['label'] in sents_dct:
            sents_dct[dct['label']].append(dct['text'])
        else:
            sents_dct[dct['label']] = [dct['text']]
            
    # TODO: check if order is same
    for label in sents_dct.keys():
        emb_dct[label] = {'emb': model.encode(sents_dct[label]), 'sent': sents_dct[label]}
    return emb_dct

def calculate_outliers(df_pd) -> dict:
    embs_dct = get_embs_for_sents(df_pd)
    mean_dct = {}
    pandas_dct = {'label': [], 'distance': [], 'text': []}
    
    # calculate mean vector per label
    for label in embs_dct:
        mean_dct[label] = embs_dct[label]['emb'].mean(axis=0)
        
    # calculate distance from the mean vector per label
    for label in embs_dct:
        mean_emb = mean_dct[label]
        for (sent_emb, sent) in zip(embs_dct[label]['emb'], embs_dct[label]['sent']):
            dist = np.linalg.norm(mean_emb - sent_emb)
            pandas_dct['label'].append(label)
            pandas_dct['distance'].append(dist)
            pandas_dct['text'].append(sent)                        
    return pd.DataFrame.from_dict(pandas_dct)

def get_seed_sentences_per_labels(outliers_df, dct_phrases: dict) -> dict:
    dct_seeds_per_label = {}
    for label in dct_phrases.keys():
        no_samples = len(dct_phrases[label])
        sub_outlier_df = outliers_df[outliers_df['label'] == label].sort_values(by=['distance'], ascending=False)
        dct_seeds_per_label[label] = list(sub_outlier_df.head(no_samples)['text'])
    return dct_seeds_per_label

# %% [markdown]
# ## all the good things

# %%
NO_TRY = 0

N_SAMPLES = 6
get_subsampled = df_train.groupby('label', group_keys=False).apply(lambda x: x.sample(N_SAMPLES))

get_subsampled.to_csv('challenge_data_new/20news/gpt4/'+str(NO_TRY)+'/seeds.csv', index=False)

# %%
dct_phrases = {}
for key in set(get_subsampled['label']):
    dct_phrases[key] = list(get_subsampled[get_subsampled['label'] == key]['text'])

default_prompt = 'Rephrase an original question or statement 3 times. Original phrase: "{}".'

# %%
dct_final_prompts = {}

for key in dct_phrases:
    dct_final_prompts[key] = []
    for phrase in dct_phrases[key]:
        dct_final_prompts[key].append((default_prompt.format(phrase), phrase))

# %%
def collect_samples(dct_final_prompts):
    dct_responses = {}

    for idx, key in enumerate(dct_final_prompts):
        print(str(idx))
        dct_responses[key] = []
        for prompt in dct_final_prompts[key]:
            print(prompt[0])
            response = request_with_checks(prompt[0])
            dct_responses[key].append((response, prompt[1]))
            time.sleep(1)
            
    return dct_responses

# %%
dct_responses = collect_samples(dct_final_prompts)
# Out:
# 0
# Rephrase an original question or statement 3 times. Original phrase: "we still dont know much about darren aronofskys upcoming movie".
# Rephrase an original question or statement 3 times. Original phrase: "prince forever".
# Rephrase an original question or statement 3 times. Original phrase: "more of this please".
# Rephrase an original question or statement 3 times. Original phrase: "on wednesday american idol crowned its new champion phillip phillips a 21yearold crooner from georgia however not".
# Rephrase an original question or statement 3 times. Original phrase: "the latenight host nails why tech tyrants dont care about truth social".
# Rephrase an original question or statement 3 times. Original phrase: "i feel like people make such a big deal out of sexuality it’s so weird to me because at the end of the day it’s just about soul connection".
# 1
# Rephrase an original question or statement 3 times. Original phrase: "what do you do all day about three weeks ago john texted me and i texted back about getting our boys together i didn’t".
# Rephrase an original question or statement 3 times. Original phrase: "even babies have bad hair days and many moms get the photographic evidence to prove it below is a collection of our favorite".
# Rephrase an original question or statement 3 times. Original phrase: "not sure how to talk about sex with your child many moms recommend using a book to help explain how babies are made in an".
# Rephrase an original question or statement 3 times. Original phrase: "i just stood there in a splitsecond of freezing january clarity watching the inferno giving us the finger as it dangled out of my daughters bedroom window and did its thing".
# Rephrase an original question or statement 3 times. Original phrase: "no one is perfect not your kids not you and certainly not me i’m a parenting expert educator and coach and i am not".
# Rephrase an original question or statement 3 times. Original phrase: "wed been home four days from the hospital when the phone rang hello an ebullient voice sang through the receiver its winnie calling to wish sophia a happy second thursday".
# 2
# Rephrase an original question or statement 3 times. Original phrase: "well we can all relax now senator john mccain who was wrong about iraq wrong about the surge in iraq wrong about the surge in afghanistan wrong about libya and wrong about most everything else pertaining to us security has vetted the syrian rebels he now wants to send arms to".
# Rephrase an original question or statement 3 times. Original phrase: "but new photos have surfaced that make our adoration for the former oc star shes always be summer to us grow even".
# 4
# Rephrase an original question or statement 3 times. Original phrase: "travel stress might not be all that bad  at least thats what people told orbitz about their past travel experiences in fact 71 percent of those travelers said their trips werent stressful at all take a look at how you can stay serene this holiday season".
# Rephrase an original question or statement 3 times. Original phrase: "if anyone would have mentioned namibia to me five years ago i dont think i would have been able to tell you where in africa it was much less want to pack my bags and go but after being on safari in kenya and tanzania i was ready for a different africa and namibia fit the bill".
# Rephrase an original question or statement 3 times. Original phrase: "what surprised me was that following the initial excitement of seeing the sharks up close my mood turned quite quickly to being calm and peaceful".
# Rephrase an original question or statement 3 times. Original phrase: "as you consider a spring getaway make sure to take note of one of the countrys bestkept secrets the blackberry farm located in east tennessee the 4200acre private estate is surrounded by lush green scenery unparalleled luxury southern hospitality and gourmet cuisine".
# Rephrase an original question or statement 3 times. Original phrase: "when traveling its not always the typical tourist traps that offer the most memorable experiences eiffel tower been there done that trevi fountain meh far more interesting are the places you dont see at first glance".
# Rephrase an original question or statement 3 times. Original phrase: "call them the ultimate place settings these restaurants around the world offer jawdropping scenery along with meals worth".
# 5
# Rephrase an original question or statement 3 times. Original phrase: "because we know that we can always get on facebook or tweet or text the very manner in which we are interacting in the physical world has changed  we are less engaged and less committed less dependent upon this moment of being together for connection and emotional nourishment".
# Rephrase an original question or statement 3 times. Original phrase: "at the yearly physical just about every aspect of your physiology is poked prodded and tested  and often by someone you".
# Rephrase an original question or statement 3 times. Original phrase: "there is no question that in order to become skillful at any sport or fitness activity you need to participate in and practice the activity but if that is all that is required  practice practice practice  how come not everyone that practices a lot excels at what they do".
# Rephrase an original question or statement 3 times. Original phrase: "we often hear calls and initiatives for selfgrowth but what i have come to realize is that we cannot truly understand what selfgrowth means until we understand separately what self means and what growth means".
# Rephrase an original question or statement 3 times. Original phrase: "1 accept things as they are not as you wish they were or ought to be 36 ignore the critics because you know the real truth".
# Rephrase an original question or statement 3 times. Original phrase: "need help with substance abuse or mental health issues in the us call 800662help 4357 for the samhsa national helpline".

# %%
fb_0 = filter_responses(dct_responses)
fb_0.drop_duplicates().to_csv('challenge_data_new/20news/gpt4/'+str(NO_TRY)+'/yelp_1_seeds.csv', index=False)

# %%
fb_0 = pd.read_csv('challenge_data_new/20news/gpt4/'+str(NO_TRY)+'/yelp_0_seeds.csv')
dct_phrases = fb_0.groupby('label')['seed'].apply(set).to_dict()
dct_taboo = get_taboo_w_for_df_no_ner(fb_0, 3, dct_phrases)

# %%
defaul_taboo_prompt = 'Rephrase an original question or statement 3 times. Original phrase: "{}". Don’t use the words “{}”, “{}” or “{}” in your responses.'

dct_final_prompts = {}

for key in dct_phrases:
    dct_final_prompts[key] = []
    for phrase in dct_phrases[key]:
        dct_final_prompts[key].append((defaul_taboo_prompt.format(phrase, dct_taboo[key][0], dct_taboo[key][1], dct_taboo[key][2]), phrase))

# %%
dct_responses = collect_samples(dct_final_prompts)
# Out:
# 0
# Rephrase an original question or statement 3 times. Original phrase: "we still dont know much about darren aronofskys upcoming movie". Don’t use the words “yet”, “one” or “since” in your responses.
# Rephrase an original question or statement 3 times. Original phrase: "prince forever". Don’t use the words “yet”, “one” or “since” in your responses.
# Rephrase an original question or statement 3 times. Original phrase: "the latenight host nails why tech tyrants dont care about truth social". Don’t use the words “yet”, “one” or “since” in your responses.
# Rephrase an original question or statement 3 times. Original phrase: "i feel like people make such a big deal out of sexuality it’s so weird to me because at the end of the day it’s just about soul connection". Don’t use the words “yet”, “one” or “since” in your responses.
# Rephrase an original question or statement 3 times. Original phrase: "on wednesday american idol crowned its new champion phillip phillips a 21yearold crooner from georgia however not". Don’t use the words “yet”, “one” or “since” in your responses.
# Rephrase an original question or statement 3 times. Original phrase: "more of this please". Don’t use the words “yet”, “one” or “since” in your responses.
# 1
# Rephrase an original question or statement 3 times. Original phrase: "no one is perfect not your kids not you and certainly not me i’m a parenting expert educator and coach and i am not". Don’t use the words “since”, “us” or “even” in your responses.
# Rephrase an original question or statement 3 times. Original phrase: "even babies have bad hair days and many moms get the photographic evidence to prove it below is a collection of our favorite". Don’t use the words “since”, “us” or “even” in your responses.
# Rephrase an original question or statement 3 times. Original phrase: "wed been home four days from the hospital when the phone rang hello an ebullient voice sang through the receiver its winnie calling to wish sophia a happy second thursday". Don’t use the words “since”, “us” or “even” in your responses.
# Rephrase an original question or statement 3 times. Original phrase: "what do you do all day about three weeks ago john texted me and i texted back about getting our boys together i didn’t". Don’t use the words “since”, “us” or “even” in your responses.
# Rephrase an original question or statement 3 times. Original phrase: "not sure how to talk about sex with your child many moms recommend using a book to help explain how babies are made in an". Don’t use the words “since”, “us” or “even” in your responses.
# Rephrase an original question or statement 3 times. Original phrase: "i just stood there in a splitsecond of freezing january clarity watching the inferno giving us the finger as it dangled out of my daughters bedroom window and did its thing". Don’t use the words “since”, “us” or “even” in your responses.
# 2
# Rephrase an original question or statement 3 times. Original phrase: "the president was at ease among his supporters". Don’t use the words “yet”, “years” or “president” in your responses.
# Rephrase an original question or statement 3 times. Original phrase: "its not just about voting for a president he said". Don’t use the words “yet”, “years” or “president” in your responses.
# Rephrase an original question or statement 3 times. Original phrase: "tfw you realize youve lost your luggage during a live tv interview". Don’t use the words “yet”, “years” or “president” in your responses.
# Rephrase an original question or statement 3 times. Original phrase: "well we can all relax now senator john mccain who was wrong about iraq wrong about the surge in iraq wrong about the surge in afghanistan wrong about libya and wrong about most everything else pertaining to us security has vetted the syrian rebels he now wants to send arms to". Don’t use the words “yet”, “years” or “president” in your responses.
# Rephrase an original question or statement 3 times. Original phrase: "its been around for more than a millennium but really find something new". Don’t use the words “yet”, “years” or “president” in your responses.
# Rephrase an original question or statement 3 times. Original phrase: "he said the presidents scorn is galvanizing people to fight global warming". Don’t use the words “yet”, “years” or “president” in your responses.
# 3
# Rephrase an original question or statement 3 times. Original phrase: "theyre different ages and all boast different styles but miley cyrus jessica simpson and alessandra ambrosio do have at". Don’t use the words “days”, “one” or “style” in your responses.
# Rephrase an original question or statement 3 times. Original phrase: "but days impeccably tailored suits elegant evening gowns and pastel nightgowns make todays style seem so lackluster and". Don’t use the words “days”, “one” or “style” in your responses.
# Rephrase an original question or statement 3 times. Original phrase: "from saucy glossie greetings glosslings  im trying to get this week off to a good start and sometimes that means getting". Don’t use the words “days”, “one” or “style” in your responses.
# Rephrase an original question or statement 3 times. Original phrase: "reddit was certainly not amused". Don’t use the words “days”, “one” or “style” in your responses.
# Rephrase an original question or statement 3 times. Original phrase: "we couldn’t wait to get huffpost style editorial fellow chanel’s golden skin into one of our favorite products from actress". Don’t use the words “days”, “one” or “style” in your responses.
# Rephrase an original question or statement 3 times. Original phrase: "but new photos have surfaced that make our adoration for the former oc star shes always be summer to us grow even". Don’t use the words “days”, “one” or “style” in your responses.
# 4
# Rephrase an original question or statement 3 times. Original phrase: "as you consider a spring getaway make sure to take note of one of the countrys bestkept secrets the blackberry farm located in east tennessee the 4200acre private estate is surrounded by lush green scenery unparalleled luxury southern hospitality and gourmet cuisine". Don’t use the words “style”, “state” or “travel” in your responses.
# Rephrase an original question or statement 3 times. Original phrase: "when traveling its not always the typical tourist traps that offer the most memorable experiences eiffel tower been there done that trevi fountain meh far more interesting are the places you dont see at first glance". Don’t use the words “style”, “state” or “travel” in your responses.
# Rephrase an original question or statement 3 times. Original phrase: "travel stress might not be all that bad  at least thats what people told orbitz about their past travel experiences in fact 71 percent of those travelers said their trips werent stressful at all take a look at how you can stay serene this holiday season". Don’t use the words “style”, “state” or “travel” in your responses.
# Rephrase an original question or statement 3 times. Original phrase: "call them the ultimate place settings these restaurants around the world offer jawdropping scenery along with meals worth". Don’t use the words “style”, “state” or “travel” in your responses.
# Rephrase an original question or statement 3 times. Original phrase: "if anyone would have mentioned namibia to me five years ago i dont think i would have been able to tell you where in africa it was much less want to pack my bags and go but after being on safari in kenya and tanzania i was ready for a different africa and namibia fit the bill". Don’t use the words “style”, “state” or “travel” in your responses.
# Rephrase an original question or statement 3 times. Original phrase: "what surprised me was that following the initial excitement of seeing the sharks up close my mood turned quite quickly to being calm and peaceful". Don’t use the words “style”, “state” or “travel” in your responses.
# 5
# Rephrase an original question or statement 3 times. Original phrase: "because we know that we can always get on facebook or tweet or text the very manner in which we are interacting in the physical world has changed  we are less engaged and less committed less dependent upon this moment of being together for connection and emotional nourishment". Don’t use the words “since”, “state” or “less” in your responses.
# Rephrase an original question or statement 3 times. Original phrase: "there is no question that in order to become skillful at any sport or fitness activity you need to participate in and practice the activity but if that is all that is required  practice practice practice  how come not everyone that practices a lot excels at what they do". Don’t use the words “since”, “state” or “less” in your responses.
# Rephrase an original question or statement 3 times. Original phrase: "we often hear calls and initiatives for selfgrowth but what i have come to realize is that we cannot truly understand what selfgrowth means until we understand separately what self means and what growth means". Don’t use the words “since”, “state” or “less” in your responses.
# Rephrase an original question or statement 3 times. Original phrase: "need help with substance abuse or mental health issues in the us call 800662help 4357 for the samhsa national helpline". Don’t use the words “since”, “state” or “less” in your responses.
# Rephrase an original question or statement 3 times. Original phrase: "at the yearly physical just about every aspect of your physiology is poked prodded and tested  and often by someone you". Don’t use the words “since”, “state” or “less” in your responses.
# Rephrase an original question or statement 3 times. Original phrase: "1 accept things as they are not as you wish they were or ought to be 36 ignore the critics because you know the real truth". Don’t use the words “since”, “state” or “less” in your responses.

# %%
fb_0 = filter_responses(dct_responses)
fb_0.drop_duplicates().to_csv('challenge_data_new/20news/gpt4/'+str(NO_TRY)+'/yelp_1_taboo.csv', index=False)

# %%
fb_0 = pd.read_csv('challenge_data_new/20news/gpt4/'+str(NO_TRY)+'/yelp_0_seeds.csv').drop_duplicates()
dct_phrases = fb_0.groupby('label')['seed'].apply(set).to_dict()

df_outliers = calculate_outliers(fb_0)
dct_phrases = get_seed_sentences_per_labels(df_outliers, dct_phrases)

# %%
default_prompt = 'Rephrase an original question or statement 3 times. Original phrase: "{}".'

dct_final_prompts = {}

for key in dct_phrases:
    dct_final_prompts[key] = []
    for phrase in dct_phrases[key]:
        dct_final_prompts[key].append((default_prompt.format(phrase), phrase))

# %%
dct_responses = collect_samples(dct_final_prompts)
# Out:
# 0
# Rephrase an original question or statement 3 times. Original phrase: "forever a prince".
# Rephrase an original question or statement 3 times. Original phrase: "endlessly a nobleman".
# Rephrase an original question or statement 3 times. Original phrase: "unendingly royal".
# Rephrase an original question or statement 3 times. Original phrase: "may i request additional quantities of this please".
# Rephrase an original question or statement 3 times. Original phrase: "a 21yearold vocalist from georgia phillip phillips was named the latest champion of american idol on wednesday despite some disagreement over the decision".
# 5
# Rephrase an original question or statement 3 times. Original phrase: "if you require assistance with substance addiction or mental health concerns in the united states contact the samhsa national helpline at 800662help 4357".
# Rephrase an original question or statement 3 times. Original phrase: "for aid with substance dependence or mental health difficulties in the us get in touch with the samhsa national helpline by calling 800662help 4357".
# Rephrase an original question or statement 3 times. Original phrase: "during the annual checkup almost every part of your bodys physiology is examined prodded and assessed frequently by someone you know".
# Rephrase an original question or statement 3 times. Original phrase: "recognize and accept things in their current state instead of your preferred or expected state 36 ignore negative opinions because your knowledge of the authentic truth is solid".
# Rephrase an original question or statement 3 times. Original phrase: "at each years health examination virtually all elements of your physical state are inspected nudged and evaluated usually by a person with whom youre acquainted".
# Rephrase an original question or statement 3 times. Original phrase: "struggling with substance misuse or mental wellbeing problems in the us dial 800662help 4357 to reach the samhsa national helpline for support".

# %%
fb_0 = filter_responses(dct_responses)
fb_0.drop_duplicates().to_csv('challenge_data_new/20news/gpt4/'+str(NO_TRY)+'/yelp_1_chaining.csv', index=False)

# %%
default_prompt = """Rephrase an original question or statement 3 times. Original phrase: "{}".
###
Example paraphrases:
{}
###
"""

default_hint_prompt = '"{}".'

def get_hint_sentences_per_labels(df_outliers, no_samples, dct_phrases):
    dct_hints_per_sample = {}
    for label in dct_phrases.keys():
        for phrase in dct_phrases[label]:
            sub_df = df_outliers[df_outliers['seed'] == phrase] 
            sub_df = sub_df.sort_values(by=['distance'], ascending=False)
            dct_hints_per_sample[phrase] = list(sub_df.head(no_samples)['text'])
    return dct_hints_per_sample

fb_0 = pd.read_csv('challenge_data_new/20news/gpt4/'+str(NO_TRY)+'/yelp_0_seeds.csv').drop_duplicates()
dct_phrases = fb_0.groupby('label')['seed'].apply(set).to_dict()
# comb is done for the second round

df_outliers = calculate_outliers(fb_0)

df_merged = df_outliers.merge(fb_0, how='inner', on='text').drop_duplicates()[['label_x', 'text', 'distance', 'seed']]
df_merged = df_merged.rename(columns={'label_x': 'label'})

dct_hints_per_sample = get_hint_sentences_per_labels(df_merged, 3, dct_phrases)

# %%
dct_final_prompts = {}

for key in dct_phrases:
    dct_final_prompts[key] = []
    for phrase in dct_phrases[key]:
        hints = dct_hints_per_sample[phrase]
        str_hints = []
        for hint in hints:
            str_hints.append(default_hint_prompt.format(hint))
        final_hint_str = "\n".join(str_hints) 
        dct_final_prompts[key].append((default_prompt.format(phrase, final_hint_str), phrase))

# %%
dct_responses = collect_samples(dct_final_prompts)
# Out:
# 0
# Rephrase an original question or statement 3 times. Original phrase: "we still dont know much about darren aronofskys upcoming movie".
# ###
# Example paraphrases:
# "theres still limited information available about darren aronofskys forthcoming film".
# "not much is yet known regarding the new movie set to be released by darren aronofsky".
# "details remain scarce pertaining to the upcoming film by darren aronofsky".
# ###
#
# Rephrase an original question or statement 3 times. Original phrase: "prince forever".
# ###
# Example paraphrases:
# "forever a prince".
# "endlessly a nobleman".
# "unendingly royal".
# ###
#
# Rephrase an original question or statement 3 times. Original phrase:

# ###
#
# Rephrase an original question or statement 3 times. Original phrase: "there is no question that in order to become skillful at any sport or fitness activity you need to participate in and practice the activity but if that is all that is required  practice practice practice  how come not everyone that practices a lot excels at what they do".
# ###
# Example paraphrases:
# "undoubtedly becoming proficient in any athletic or physical exercise necessitates engagement and repetition yet if continuously practicing is all that it takes how come several individuals who train extensively dont always excel in their field".
# "to be skilled at any sportsrelated or fitness endeavor there must undoubtedly be an involvement in steady practicing of the activity but if it only demands continuous hard work why isnt every person who dedicates themselves to practice achieving outstanding results".
# "its undeniable that to improve at any sport or fitness activity participation and practice are essential but if the only requirement is to constantly practice why doesnt everyone who puts in the effort become exceptional at what they do".
# ###
#
# Rephrase an original question or statement 3 times. Original phrase: "we often hear calls and initiatives for selfgrowth but what i have come to realize is that we cannot truly understand what selfgrowth means until we understand separately what self means and what growth means".
# ###
# Example paraphrases:
# "there is often talk about pursuing selfenhancement but what ive realized is that truly grasping its essence depends on separately examining the definitions of self and growth".
# "frequently we encounter appeals and efforts promoting selfimprovement however it has become evident that comprehending the concept of selfgrowth requires an individual understanding of both self and growth".
# "we regularly come across suggestions encouraging personal development but its essential to acknowledge that a genuine grasp of selfexpansion cannot be achieved without first dissecting the meanings behind ‘self’ and ‘growth”".
# ###
#
# Rephrase an original question or statement 3 times. Original phrase: "need help with substance abuse or mental health issues in the us call 800662help 4357 for the samhsa national helpline".
# ###
# Example paraphrases:
# "if you require assistance with substance addiction or mental health concerns in the united states contact the samhsa national helpline at 800662help 4357".
# "for aid with substance dependence or mental health difficulties in the us get in touch with the samhsa national helpline by calling 800662help 4357".
# "struggling with substance misuse or mental wellbeing problems in the us dial 800662help 4357 to reach the samhsa national helpline for support".
# ###
#
# Rephrase an original question or statement 3 times. Original phrase: "at the yearly physical just about every aspect of your physiology is poked prodded and tested  and often by someone you".
# ###
# Example paraphrases:
# "during the annual checkup almost every part of your bodys physiology is examined prodded and assessed frequently by someone you know".
# "at each years health examination virtually all elements of your physical state are inspected nudged and evaluated usually by a person with whom youre acquainted".
# "in the routine yearly medical assessment nearly all facets of your biological functioning are scrutinized poked and analyzed commonly by an individual familiar to you".
# ###
#
# Rephrase an original question or statement 3 times. Original phrase: "1 accept things as they are not as you wish they were or ought to be 36 ignore the critics because you know the real truth".
# ###
# Example paraphrases:
# "recognize and accept things in their current state instead of your preferred or expected state 36 ignore negative opinions because your knowledge of the authentic truth is solid".
# "acknowledge situations as they exist rather than how youd like them to be or assume they must be 36 pay no attention to critics since youre aware of the actual reality".
# "embrace the reality of circumstances not what you desire or believe they should be 36 disregard any detractors for you comprehend the genuine truth".
# ###

# %%
fb_0 = filter_responses(dct_responses)
fb_0.drop_duplicates().to_csv('challenge_data_new/20news/gpt4/'+str(NO_TRY)+'/yelp_1_hints.csv', index=False)

# %% [markdown]
# ## final csvs

# %%
# temporary only
import re
import string

NO_TRY=0

fb_0 = pd.read_csv('challenge_data_new/20news/gpt4/'+str(NO_TRY)+'/seeds.csv')
fb_0 = fb_0[['text', 'label']].drop_duplicates()

fb_0['text']=fb_0['text'].apply(lambda x: x.lower())
fb_0['text']=fb_0['text'].apply(lambda x: x.strip())
fb_0['text']=fb_0['text'].apply(lambda x: x.replace('"',''))
fb_0['text']=fb_0['text'].apply(lambda x: re.sub('[%s]' % re.escape(string.punctuation), '', x))

fb_0.to_csv('challenge_data_new/20news/gpt4/'+str(NO_TRY)+'/seeds.csv', index=False)

# %%
fb_seeds = pd.read_csv('challenge_data_new/20news/gpt4/'+str(NO_TRY)+'/seeds.csv').dropna().reset_index(drop=True).sample(frac=1, replace=False, random_state=1)
fb_0 = pd.read_csv('challenge_data_new/20news/gpt4/'+str(NO_TRY)+'/yelp_0_seeds.csv').dropna().reset_index(drop=True).sample(frac=1, replace=False, random_state=1)
fb_1 = pd.read_csv('challenge_data_new/20news/gpt4/'+str(NO_TRY)+'/yelp_1_seeds.csv').dropna().reset_index(drop=True).sample(frac=1, replace=False, random_state=1)

fb = pd.concat([fb_0, fb_1, fb_seeds], ignore_index=True).drop_duplicates('text').dropna(subset=['text'])

# %%
fb = fb.sample(frac=1).reset_index(drop=True)
fb['text'] = fb['text'].apply(lambda x: x.replace('"',''))
fb = fb[~fb['text'].str.contains("paraphra")]

# %%
fb[['text', 'label']].to_csv('challenge_data_new/20news/gpt4/'+str(NO_TRY)+'/fb_prompt.csv', index=False)

# %%
fb_1 = pd.read_csv('challenge_data_new/20news/gpt/'+str(NO_TRY)+'/yelp_1_taboo.csv').dropna(subset=['text']).reset_index(drop=True).sample(frac=1, replace=False, random_state=1)


fb = pd.concat([fb_0, fb_1, fb_seeds], ignore_index=True).drop_duplicates('text').dropna(subset=['text'])
fb = fb[~fb['text'].str.contains("paraphra")]

fb = fb.sample(frac=1).reset_index(drop=True)
fb['text'] = fb['text'].apply(lambda x: x.replace('"',''))

fb[['text', 'label']].to_csv('challenge_data_new/20news/gpt4/'+str(NO_TRY)+'/fb_taboo.csv', index=False)

# %%
fb_1 = pd.read_csv('challenge_data_new/20news/gpt/'+str(NO_TRY)+'/yelp_1_chaining.csv').dropna(subset=['text']).reset_index(drop=True).sample(frac=1, replace=False, random_state=1)

fb = pd.concat([fb_0, fb_1, fb_seeds], ignore_index=True).drop_duplicates('text').dropna(subset=['text'])
fb = fb[~fb['text'].str.contains("paraphra")]

fb = fb.sample(frac=1).reset_index(drop=True)
fb['text'] = fb['text'].apply(lambda x: x.replace('"',''))

fb[['text', 'label']].to_csv('challenge_data_new/20news/gpt4/'+str(NO_TRY)+'/fb_chaining.csv', index=False)

# %%
fb_1 = pd.read_csv('challenge_data_new/20news/gpt/'+str(NO_TRY)+'/yelp_1_hints.csv').dropna(subset=['text']).reset_index(drop=True).sample(frac=1, replace=False, random_state=1)

fb = pd.concat([fb_0, fb_1, fb_seeds], ignore_index=True).drop_duplicates('text').dropna(subset=['text'])
fb = fb[~fb['text'].str.contains("paraphra")]

fb = fb.sample(frac=1).reset_index(drop=True)
fb['text'] = fb['text'].apply(lambda x: x.replace('"',''))

fb[['text', 'label']].to_csv('challenge_data_new/20news/gpt4/'+str(NO_TRY)+'/fb_hints.csv', index=False)
